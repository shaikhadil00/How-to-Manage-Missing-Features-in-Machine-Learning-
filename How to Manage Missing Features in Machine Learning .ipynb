# %% [markdown]
# ![Screenshot%202024-12-03%20111851.png](attachment:Screenshot%202024-12-03%20111851.png)

# %% [markdown]
# # Above Data represent the small sample data

# %% [markdown]
# # where Emp ID , Advertising , Age , Exprience is independent variable

# %% [markdown]
# # Sales is Dependent variable

# %% [markdown]
# # To Handle missing value these 3 Types are there

# %% [markdown]
# ![Screenshot%202024-12-03%20111931.png](attachment:Screenshot%202024-12-03%20111931.png)

# %% [markdown]
# # Remove the record

# %% [markdown]
#  If we are working on a large datasets i.e(1k or above) so we can remove missing entry

# %% [markdown]
# # Create sub model

# %%
while training model we hv to give all entries present in missing value for prediction to get the output for missing value

# %%
Ex. Emp ID - 8  
Advertising - 2400
Age - 60
Exprience - 4

# %%
so we have to give all the independent entries to get Dependent entries

# %% [markdown]
# # Automatic strategy

# %%
mean :- Add all the output divide with total no. of entries present

# %%
median :- segregate the output in order wise and find out which no. is in middle so we can add the no. in missing value

# %%
mode :- mode is about to check no. which is repeated more than any of number so in missing value we can put

# %% [markdown]
# # These are the method which we can solve or handle missing value
